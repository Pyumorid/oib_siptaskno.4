# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
sms = pd.read_csv("C:\\Users\\91915\\Downloads\\spam folder.csv", encoding = "ISO-8859-1", usecols=[0,1], skiprows=1)
sms.head()
# Out:
#     ham  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4  spam
#
#   Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                      Ok lar... Joking wif u oni...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  U dun say so early hor... U c already then say...
# 3  Nah I don't think he goes to usf, he lives aro...
# 4  FreeMsg Hey there darling it's been 3 week's n...

# %%
sms.shape
# Out:
# (5571, 2)

# %%
sms.info
# Out:
# <bound method DataFrame.info of        ham  \
# 0      ham
# 1     spam
# 2      ham
# 3      ham
# 4     spam
# ...    ...
# 5566  spam
# 5567   ham
# 5568   ham
# 5569   ham
# 5570   ham
#
#      Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                         Ok lar... Joking wif u oni...
# 1     Free entry in 2 a wkly comp to win FA Cup fina...
# 2     U dun say so early hor... U c already then say...
# 3     Nah I don't think he goes to usf, he lives aro...
# 4     FreeMsg Hey there darling it's been 3 week's n...
# ...                                                 ...
# 5566  This is the 2nd time we have tried 2 contact u...
# 5567              Will Ì_ b going to esplanade fr home?
# 5568  Pity, * was in mood for that. So...any other s...
# 5569  The guy did some bitching but I acted like i'd...
# 5570                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]>

# %%
sms.nunique
# Out:
# <bound method DataFrame.nunique of        ham  \
# 0      ham
# 1     spam
# 2      ham
# 3      ham
# 4     spam
# ...    ...
# 5566  spam
# 5567   ham
# 5568   ham
# 5569   ham
# 5570   ham
#
#      Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                         Ok lar... Joking wif u oni...
# 1     Free entry in 2 a wkly comp to win FA Cup fina...
# 2     U dun say so early hor... U c already then say...
# 3     Nah I don't think he goes to usf, he lives aro...
# 4     FreeMsg Hey there darling it's been 3 week's n...
# ...                                                 ...
# 5566  This is the 2nd time we have tried 2 contact u...
# 5567              Will Ì_ b going to esplanade fr home?
# 5568  Pity, * was in mood for that. So...any other s...
# 5569  The guy did some bitching but I acted like i'd...
# 5570                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]>

# %%
sms.columns
# Out:
# Index(['ham', 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'], dtype='object')

# %%
sms.columns=['Ham','go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat']

# %%
sms.isnull().sum()
# Out:
# Ham                                                                                                 0
# go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat    0
# dtype: int64

# %%
sms.describe()
# Out:
#          Ham  \
# count   5571
# unique     2
# top      ham
# freq    4824
#
#        go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat
# count                                                5571
# unique                                               5168
# top                                Sorry, I'll call later
# freq                                                   30

# %%
sms["Ham"].unique
# Out:
# <bound method Series.unique of 0        ham
# 1       spam
# 2        ham
# 3        ham
# 4       spam
#         ...
# 5566    spam
# 5567     ham
# 5568     ham
# 5569     ham
# 5570     ham
# Name: Ham, Length: 5571, dtype: object>

# %%
sms.groupby("Ham").size()
# Out:
# Ham
# ham     4824
# spam     747
# dtype: int64

# %%
sms_counts=sms['Ham'].value_counts()
print("count of the Ham column")
print(sms_counts)
# Out:
# count of the Ham column
# ham     4824
# spam     747
# Name: Ham, dtype: int64

# %%
sms_counts=sms['go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat'].value_counts()
print("count of go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat column")
print(sms_counts)
# Out:
# count of go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat column
# Sorry, I'll call later                                                                                                                                                                 30
# I cant pick the phone right now. Pls send a message                                                                                                                                    12
# Ok...                                                                                                                                                                                  10
# Wen ur lovable bcums angry wid u, dnt take it seriously.. Coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... Have nice day da.     4
# ...

# %%
sms.head
# Out:
# <bound method NDFrame.head of        Ham  \
# 0      ham
# 1     spam
# 2      ham
# 3      ham
# 4     spam
# ...    ...
# 5566  spam
# 5567   ham
# 5568   ham
# 5569   ham
# 5570   ham
#
#      go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat
# 0                         Ok lar... Joking wif u oni...
# 1     Free entry in 2 a wkly comp to win FA Cup fina...
# 2     U dun say so early hor... U c already then say...
# 3     Nah I don't think he goes to usf, he lives aro...
# 4     FreeMsg Hey there darling it's been 3 week's n...
# ...                                                 ...
# 5566  This is the 2nd time we have tried 2 contact u...
# 5567              Will Ì_ b going to esplanade fr home?
# 5568  Pity, * was in mood for that. So...any other s...
# 5569  The guy did some bitching but I acted like i'd...
# 5570                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]>

# %%
import seaborn as sns

# %%
plt.bar(sms['Ham'],sms['go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat'])
plt.title("go until jurong point Crazy....available only in bugis n great la buffet cine there got more wat vs Ham")
plt.xlabel("name of the Ham")
plt.ylabel("go until jurong point Crazy....available only in bugis n great la buffet cine there got more wat vs Ham")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 139 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error, mean_squared_error, r2_score 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X=sms.drop('Ham',axis=1)

# %%
X.head()
# Out:
#   go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat
# 0                      Ok lar... Joking wif u oni...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  U dun say so early hor... U c already then say...
# 3  Nah I don't think he goes to usf, he lives aro...
# 4  FreeMsg Hey there darling it's been 3 week's n...

# %%
Y=sms['go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat']

# %%
Y.head()
# Out:
# 0                        Ok lar... Joking wif u oni...
# 1    Free entry in 2 a wkly comp to win FA Cup fina...
# 2    U dun say so early hor... U c already then say...
# 3    Nah I don't think he goes to usf, he lives aro...
# 4    FreeMsg Hey there darling it's been 3 week's n...
# Name: go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat, dtype: object

# %%
Y
# Out:
# 0                           Ok lar... Joking wif u oni...
# 1       Free entry in 2 a wkly comp to win FA Cup fina...
# 2       U dun say so early hor... U c already then say...
# 3       Nah I don't think he goes to usf, he lives aro...
# 4       FreeMsg Hey there darling it's been 3 week's n...
#                               ...
# 5566    This is the 2nd time we have tried 2 contact u...
# 5567                Will Ì_ b going to esplanade fr home?
# 5568    Pity, * was in mood for that. So...any other s...
# 5569    The guy did some bitching but I acted like i'd...
# 5570                           Rofl. Its true to its name
# Name: go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat, Length: 5571, dtype: object

# %%
#split the data into training and testing sets 
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.24,random_state=20)

# %%
X_train.head()
# Out:
#      go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat
# 4486          Call me when you get the chance plz &lt;3
# 2874  Fuck cedar key and fuck her (come over anyway ...
# 3901  Waiting in e car 4 my mum lor. U leh? Reach ho...
# 2651                      No need for the drug anymore.
# 3773  Hi! You just spoke to MANEESHA V. We'd like to...

# %%
X_train.shape
# Out:
# (4233, 1)

# %%
Y_train.head()
# Out:
# 4486            Call me when you get the chance plz &lt;3
# 2874    Fuck cedar key and fuck her (come over anyway ...
# 3901    Waiting in e car 4 my mum lor. U leh? Reach ho...
# 2651                        No need for the drug anymore.
# 3773    Hi! You just spoke to MANEESHA V. We'd like to...
# Name: go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat, dtype: object

# %%
Y_train.shape
# Out:
# (4233,)

# %%
X_test.head()
# Out:
#      go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat
# 4731  Good Morning my Dear Shijutta........... Have ...
# 2315          That's cause your old. I live to be high.
# 1765  SMS AUCTION You have won a Nokia 7250i. This i...
# 5260  I absolutely LOVE South Park! I only recently ...
# 4888  Sounds like there could be a lot of time spent...

# %%
X_test.shape
# Out:
# (1338, 1)

# %%
Y_test.head()
# Out:
# 4731    Good Morning my Dear Shijutta........... Have ...
# 2315            That's cause your old. I live to be high.
# 1765    SMS AUCTION You have won a Nokia 7250i. This i...
# 5260    I absolutely LOVE South Park! I only recently ...
# 4888    Sounds like there could be a lot of time spent...
# Name: go until jurong point Crazy...available only in bugis n great la buffet cine there got amore wat, dtype: object

# %%
Y_test.shape
# Out:
# (1338,)
